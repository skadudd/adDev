# %%
import pandas as pd
from konlpy.tag import Okt
from datetime import datetime
from bs4 import BeautifulSoup
import os, re, json, random
from selenium import webdriver as wb
import codecs

# %%
def d_make_dic(words) :
    d_tmp = ["@"]
    d_dic = {}

    for word in words :
        d_tmp.append(word)
        if len(d_tmp) < 3 : continue
        if len(d_tmp) > 3 : d_tmp = d_tmp[1:]
        d_set_dic(d_dic, d_tmp)

        if word == "." :
            d_tmp = ["@"]
            continue
    
    return d_dic

# %%
def d_set_dic(dic, s3) :
    w1, w2, w3 = s3
    if not w1 in dic : dic[w1] = {}
    if not w2 in dic[w1] : dic[w1][w2] = {}
    if not w3 in dic[w1][w2] : dic[w1][w2][w3] = 0 # 이상징후
    dic[w1][w2][w3] += 1

# %%
def d_make_sentence(dic) :
    d_ret = []
    if not "@" in dic : return "no Dic"
    d_top = dic["@"]

    w1 = d_word_choice(d_top)
    w2 = d_word_choice(d_top[w1])

    d_ret.append(w1)
    d_ret.append(w2)

    while True :
        try:
            w3 = d_word_choice(dic[w1][w2])
            print( w3 )
            d_ret.append(w3)
        except Exception as e :
            print("error : ", e)
            break
        
        if w3 == "." : break
        w1, w2 = w2, w3
    d_ret = "".join(d_ret)

    options = wb.ChromeOptions()
    options.add_argument('headless')
    options.add_argument('window-size=1920x1080')
    options.add_argument("disable-gpu")

    d_browser = wb.Chrome("./chromedriver", options = options)
    d_browser.get("https://search.naver.com/search.naver?ie=utf8&query=%EB%84%A4%EC%9D%B4%EB%B2%84+%EB%A7%9E%EC%B6%A4%EB%B2%95+%EA%B2%80%EC%82%AC%EA%B8%B0")

    d_browser.implicitly_wait(2)
    d_textfield = d_browser.find_element_by_css_selector("#grammar_checker > div > div.api_cs_wrap > div.check_box > div.text_box._original > div > div.text_area > textarea")
    d_textfield.clear()
    d_textfield.send_keys(d_ret)

    d_browser.implicitly_wait(2)
    d_clicked = d_browser.find_element_by_css_selector("#grammar_checker > div > div.api_cs_wrap > div.check_box > div.text_box._original > div > div.check_info > button")
    d_clicked.click()

    d_browser.implicitly_wait(2)
    d_text = d_browser.find_element_by_css_selector("#grammar_checker > div > div.api_cs_wrap > div.check_box > div.text_box.right._result.result > div > div.text_area > p")

    return d_text.text

# %%
def d_word_choice(sel) :
    d_keys = sel.keys()
    return random.choice(list(d_keys))

# %%
def ads_create_contents(z_file_text) :
    
    # d_dict_file = z_file_path + ( str(z_file_client) + ".json" )
    d_dict_file = "/Users/young/dataset_local/6_my_078.json"
    
    if not os.path.exists(d_dict_file) :
        d_file_output = codecs.open(z_file_text, "r", encoding = "utf-16")
        soup = BeautifulSoup(d_file_output, "lxml")
            
        body = soup.select_one("body")
        text = body.getText()
        text = text.replace("…", "")

        d_Okt = Okt()
        d_malist = d_Okt.pos(text, norm = True)
        words = []


        for word in d_malist :
            if not word[1] in ["Punctuation"] :
                words.append( word[0] )
            if word[0] == "." :
                words.append( word[0] )
        
        dic = d_make_dic(words)
        json.dump( dic, open(d_dict_file, "w", encoding = "utf-8") )

    else :
        dic = json.load(open(d_dict_file, "r"))

    cnt = int(input("필요한 콘텐츠 수 : "))

    d_save_list = []
    
    for i in range(cnt) :
        d_sentence = d_make_sentence(dic)
        d_save_list.append( d_sentence )
        print(d_sentence)
        print("------------------")


    d_save_dataframe = pd.DataFrame( d_save_list )

    d_save_date = datetime.now()
    # d_save_name = z_file_path + str(z_file_client) + "_" + str(d_save_date.hour) + "_" + str(d_save_date.minute) + ".xlsx"
    d_save_name = '/Users/young/Desktop/test.xlsx'
    d_save_dataframe.to_excel(d_save_name, sheet_name = "DATASET", header = ["문장 콘텐츠"])

# %%
import pymysql
import re

def ads_create_database(file_path) :

    con = pymysql.connect(host="localhost", user="root", passwd="135790", db="adsDB", charset="utf8")
    cursor = con.cursor()

    # DataBase 첫 테이블 생성
    # cursor.execute("CREATE TABLE adsTable (adsId INT(10) NOT NULL AUTO_INCREMENT PRIMARY KEY, adsCategory VARCHAR(3000) NOT NULL, adsCopyright VARCHAR(3000) NOT NULL) CHARACTER SET utf8")
    

    # 데이터 삽입
    # df = pd.read_excel( file_path, "DATASET" )

    # for i in range( len(df) ) :
    #     txt = re.sub('[^A-Za-z0-9가-힣\s]', '', df['콘텐츠 제목'][i])

    #     cursor.execute(" INSERT INTO adsTable VALUES('{}', '{}', '{}') ".format(i+1, "Food_Dining", txt))
    #     print( "전체 {} 개 중, 현재 {} 개 DB INSERT 완료 ..".format(len(df), i+1) )
    # con.commit()


    # 
    sqldf = pd.read_sql("SELECT adsCategory, adsCopyright FROM adsDB.adsTable", con)

    f = open(z_file_path + "max.txt", "w", encoding='utf16')
    
    for i in range( len(sqldf) ) :
        if i == 0 :
            f.write("<body> \n\n")
        else :
            f.write("<p>{}</p> \n".format( sqldf['adsCopyright'][i] ) )

    f.write("\n </body>")
    f.close()

    import time
    time.sleep(1)

    ads_create_contents("max.txt")

if __name__ == "__main__" :

    z_owner_name = "6_my"
    z_owner_code = "078"

    # new_in_path_json = 'Users/young/dataset_local/6_my_078.json'
    new_in_path_txt = '/Users/young/dataset_local/max.txt'

    z_file_path = "./Clients/" + z_owner_name + "/" + z_owner_code + "/"
    print(z_file_path)
    z_file_client = z_owner_name + "_" + z_owner_code
    z_file_name = z_owner_code + ".xlsx"
    z_file_paths = z_file_path + z_file_name
    z_file_text = "max.txt"

    # ads_create_database(z_file_paths)

    

    ads_create_contents(new_in_path_txt)
# Out:
# ./Clients/6_my/078/
# 새우
# 장
# 만능
# 김치
# 양념
# .
# 양념 새우 장만 능김치 양념.
# ------------------
# 아침밥
# 상
# 순두부찌개
# 파
# 강회
# 곱창
# 돌
# 김구
# 이
# 등
# 갈비
# 매운
# 찜등
# 갈비
# 김치
# 찜
# 맛집
# 비법
# 간단한
# 저녁
# 메뉴
# 좋네요
# .
# 20220214아침 밥상 순두부찌개 파강회 곱창 돌김 구이 등갈비 매운 찜 등갈비 김치찜 맛집 비법 간단한 저녁 메뉴 좋네요.
# ------------------
# 파김치
# 담그는
# 중
# .
# 대파 김치 담그는 중.
# ------------------
# 가정식
# 수제
# 김치
# 집
# 김치
# 공
# 방
# 갓
# 담근
# 별미
# 김치
# 황제
# 돌산
# 갓김치
# 맛있게
# 담그는
# 법
# 저
# 만의
# 팁
# 이
# 들어간
# 파김치
# 담그는
# 법
# 쉽고
# 빠르고
# 맛있는
# 김치
# 김밥
# 상추
# 깻잎
# 넣은
# 참치
# 김밥
# .
# 맛있는 가정식 수제 김치집 김치곤 방갓 담근 별미김치 황제 돌산 갓김치 맛있게 담그는 법정만의 팁이 들어간 파김치 담그는 법 쉽고 빠르고 맛있는 김치 김밥 상추 깻잎 넣은 참치 김밥.
# ------------------
# 잡채
# 잡채
# 밥
# 만들기
# 달래
# 장
# 만들기
# .
# 남은 잡채 잡채밥 만들기 달래장 만들기.
# ------------------
# 배기
# 김치
# 만드는
# 법
# 무
# 김치
# 오
# 리지
# 널
# 버전
# .
# 알배기 김치 만드는 법무 김치 오리지널 버전.
# ------------------
# 국수
# 겨울
# 밤
# 야식
# 속이
# 뻥
# 뚫리는
# 물김치
# 설명
# 절
# 개운하고
# 쨍
# 한
# 배추
# 물김치
# 김장
# 김치
# 를
# 넣어서
# 원
# 팬
# 요리
# .
# 김치말이국수 겨울밤 야식 속이 뻥 뚫리는 물김치 설 명절 개운하고 쨍한 배추 물김치 김장김치를 넣어서 원패 요리.
# ------------------
# 마늘
# 보관
# 법
# 김치냉장고
# 에
# 보관
# 해요
# 다진
# 마늘
# 은
# .
# 깐 마늘 보관법 김치냉장고에 보관해요 다진 마늘은.
# ------------------
# 저녁
# 메뉴
# 추천
# 국수
# 삶는
# 법
# 김장
# 배추
# 절
# 이기
# 와
# 김치
# 두
# 가지
# 만으로
# 간단하게
# 참치
# 김치
# 김밥
# 만드는
# 법
# 간단
# 요리
# 파
# 겉절이
# 레시피
# 쪽파
# 김치
# 만들기
# 올케
# 이거야
# .
# 간단한 저녁 메뉴 추천 국수 삶는 법 김장 배추 절이기와 김치 두 가지만으로 간단하게 참치김치 김밥 만드는 법 간단 요리사 겉절이 레시피 쪽파김치 만들기 올케 이거야.
# ------------------
# 무
# 절임
# 냉면
# 무
# 절임
# 냉면
# 무
# 절임
# 냉면
# 무
# 김치
# .
# 냉면 무 절임 냉면 무 절임 냉면 무 절임 냉면 무김치.
# ------------------
# 집
# 김치
# 가
# 생각날
# 때
# 빛
# 이나라
# 김치
# .
# 종가집김치가생각날때빛이나라김치.
# ------------------
# 선화동
# 실비
# 파김치
# 까지
# .
# 대전 선화동 실비 파김치까지.
# ------------------
# 맛있게
# 끓이는
# 돼지
# 삼겹살
# 김치찌개
# 재료
# 간단한
# 저녁
# 메뉴
# 돼지고기
# 묵은지
# 요리
# .
# 된장찌개 맛있게 끓이는 돼지 삼겹살 김치찌개 재료 간단한 저녁 메뉴 돼지고기 묵은지 요리.
# ------------------
# 레시피
# 알토
# 란
# 배추
# 물김치
# 나박김치
# 담그는
# 법
# 아
# 삭
# 시원함이
# 끝내주는
# 보리
# 김치
# .
# TV 레시피 알토란 배추 물김치 나박김치 담그는 법 아삭 시원함이 끝내주는 보리 김치.
# ------------------
# 맛있게
# 끓이는
# 돼지
# 삼겹살
# 김치찌개
# 재료
# 간단한
# 저녁
# 메뉴
# 레시피
# .
# 청국장 맛있게 끓이는 돼지 삼겹살 김치찌개 재료 간단한 저녁 메뉴 레시피.
# ------------------
# 새우
# 김치전
# 만드는
# 법
# 별미
# 신
# 김치
# 볶음
# 달콤새콤
# 맛있게
# 달달
# 볶아요
# .
# 민물새우 김치전 만드는 법별 미신 김치볶음 달콤새콤 맛있게 달달 볶아요.
# ------------------
# 볶음밥
# 오늘
# 저녁
# 뭐
# 먹지
# 베이컨
# 요리
# 김치볶음밥
# .
# 소시지 볶음밥 오늘 저녁 뭐 먹지 베이컨 요리 김치볶음밥.
# ------------------
# 때
# 딱
# 참치
# 김치전
# 레시피
# .
# 출출할 때 딱 참치김치전 레시피.
# ------------------
# 박지
# 담그기
# .
# 섞박지 담그기.
# ------------------
# 이니까
# 김치
# 만두
# 맛있게
# 만드는
# 법
# 메밀묵
# 양념장
# 아
# 삭
# 하고
# 맛있는
# 김치
# 요리
# 저녁
# 메뉴
# 김치
# 국밥
# 갱
# 시기
# 죽
# .
# 설이니까김치만두맛있게만드는법메밀묵양념장아삭하고맛있는김치요리저녁메뉴김치국밥갱시기죽.
# ------------------
# 김치전
# 만드는
# 법
# 집
# 에서
# 삼겹살
# 맛있게
# 굽는
# 법
# 사과
# 김치
# 만들기
# 냉면
# 김치
# 무
# 물김치
# 시원하게
# 담았어요
# .
# 콩나물김치전 만드는 법집에서 삼겹살 맛있게 굽는 법사가 김치 만들기 냉면 김치 물 물김치 시원하게 담았어요.
# ------------------
# 김치
# 파스타
# 만들기
# 매콤
# 과
# 담백함이
# 조화로운
# 파스타
# 종류
# 오늘
# 저녁
# 뭐
# 먹지
# 베이컨
# 요리
# 김치볶음밥
# .
# 비건김치파스타만들기매콤과담백함이조화로운파스타종류오늘저녁뭐먹지베이컨요리김치볶음밥.
# ------------------
# 레시피
# .
# 김치부침개 레시피.
# ------------------
# 전만
# 드는
# 법
# 김치
# 콩나물국
# 만드는
# 법
# 레시피
# 오징어
# 김치전
# 만들기
# .
# 녹두전 만드는 법 김치 콩나물국 만드는 법 레시피 오징어김치전 만들기.
# ------------------
# 청국장
# 끓이는
# 법
# 레시피
# 돼지
# 김치찌개
# 만드는
# 법
# 백종원
# 김치찌개
# 맛있게
# 끓이는
# 법
# 밥
# 반찬
# 깻잎
# 지
# 요리
# 레시피
# 스팸
# 넣고
# 맛있게
# 끓이는
# 법
# 보글보글
# 어묵
# 투하
# 청국장
# 찌개
# 오늘
# 저녁
# 뭐
# 먹지
# 돼지고기
# 김치찌개
# 만드는
# 법
# 코다리
# 요리
# 김치
# 만두
# 고기만
# 두
# 만들기
# 만두
# 빚
# 는
# 법
# 김치
# 명절
# 전
# 종류
# .
# 냉이청국장끓이는법레시피돼지김치찌개만드는법백종원김치찌개맛있게끓이는법밥반찬깻잎지요리레시피스팸넣고맛있게끓이는법보글보글어묵투하청국장찌개오늘저녁뭐먹지돼지고기김치찌개만드는법코다리요리김치만두고기만두만들기만두빚는법김치명절전종류.
# ------------------
# 로
# 좋은
# 볶음밥
# 종류
# .
# 속풀이로 좋은 볶음밥 종류.
# ------------------
# 무
# 피클
# 백김치
# 물김치
# 1
# 타
# 쌍피
# 국물
# 무
# 배추김치
# 어른
# 아이
# 김치
# .
# 배추 무피클 백김치 물김치 1타 쌍피 국물 무 배추김치 어른 아이김치.
# ------------------
# 김치
# 여린
# 머위
# 잎
# 겉절이
# 로
# 변신
# 봄
# 김치
# 밥
# 묵은지
# 신
# 김치
# 김치찌개
# 끓이는
# 법
# 겨울
# 국
# 요리
# .
# 머위 김치 여린 머윗잎 겉절이로 변신 봄김치밥 묵은 지신 김치 김치찌개 끓이는 법 겨울 국 요리.
# ------------------
# 무
# 김치
# .
# 냉면 무김치.
# ------------------
# 깍두기
# 명절
# 남은
# 음식
# 나박김치
# 동치미
# 국수
# 김치말이
# 국수
# 냉
# 국수
# .
# 과일 깍두기 명절 남은 음식 나박김치 동치미국수 김치말이국수 낸 국수.
# ------------------
# 돈
# 찌개
# 갓
# 김치찌개
# 얼큰해서
# 별미
# .
# 갓 둔 찌개 갓김치찌개 얼큰해서 별미.
# ------------------
# 참치
# 김치찌개
# 레시피
# 000
# 넣는
# 묵은지
# 백종원
# 김치찌개
# 맛있게
# 끓이는
# 돼지
# 삼겹살
# 김치찌개
# 만두전골
# 코
# 박고
# 퍼
# 먹었네요
# .
# 실패한 참치김치찌개 레시피 000 넣는 묵은 지 백종원 김치찌개 맛있게 끓이는 돼지 삼겹살 김치찌개 만두전골 코 박고 퍼먹었네요.
# ------------------
# 김치
# 여린
# 머위
# 잎
# 겉절이
# 로
# 변신
# 봄
# 김치
# 배추김치
# 배추
# 막
# 김치
# 맛김치
# 만들기
# 1
# 포기
# 배추김치
# 양념
# 알
# 배기
# 배추
# 겉절이
# 만들기
# 5분
# 만에
# 완성
# .
# 머위 김치 여린 머윗잎 겉절이로 변신 봄김치 배추김치 배추 막김치 맛 김치 만들기 1포기 배추김치 양념 알배기 배추 겉절이 만들기 5분 만에 완성.
# ------------------
# 담그는
# 방법
# 깔끔하고
# 시원한
# 김치
# 굴국
# 레시피
# .
# 백김치 담그는 방법 깔끔하고 시원한 김치 굴국 레시피.
# ------------------
# 분
# 수육
# 보쌈
# 무
# 김치
# 담그기
# 설렁탕
# 집
# 무
# 김치
# 같은
# 꼬들
# 한
# 식감
# 무생채
# 고추장
# 양념
# 레시피
# .
# 무수운 수육 보쌈 무김치 담그기 설렁탕집 무김치 같은 꼬들꼬들한 식감 무생채 고추장 양념 레시피.
# ------------------
# 기계로
# 김치전
# 만들기
# 역시
# 김치전
# 반죽
# 이
# .
# 와플 기계로 김치전 만들기 역시 김치전 반죽이.
# ------------------
# 아침밥
# 상
# 곰탕
# 주말
# 일상
# 파김치
# .
# 수요일 아침 밥상 곰탕 주말 일상 파김치.
# ------------------
# 치마
# 요
# 주먹밥
# 레시피
# .
# 참치마요 주먹밥 레시피.
# ------------------
# 식
# 양
# 배추김치
# 절임
# 사우어크라우트
# w
# 주비
# 푸드
# .
# 독일식양배추김치절임사우어크라우트w주비푸드.
# ------------------
# 김치
# 볶음
# 묵은
# 갓김치
# 볶음
# 레시피
# 김치
# 부추
# 넣어
# 더
# 맛있는
# 굴
# 부침개
# 만들기
# .
# 어묵 김치볶음 묵은 갓김치볶음 레시피 김치 부추 넣어 더 맛있는 굴 부침개 만들기.
# ------------------
# 살림이야기
# 브레빌
# 티
# 메이커
# 마
# 그네
# 틱
# 계량
# 스푼
# 김치
# 용기
# .
# 220224살림 이야기 브레 밀티 메이커 마그네틱 계량스푼 김치용기.
# ------------------
# 김치볶음밥
# 간단한
# 점심
# 메뉴
# .
# 베이컨 김치볶음밥 간단한 점심 메뉴.
# ------------------
# 만들기
# 만
# 두피
# 요리
# .
# 만두 만들기 만두피 요리.
# ------------------
# 만두
# 추운
# 날씨
# 에
# 오랜
# 만
# 에
# 세탁
# 점심
# 으로
# 최고
# .
# 비비고 만두 추운 날씨에 오랜만에 세탁 점심으로 최고.
# ------------------
# 닭갈비
# 레시피
# 김치
# 치즈
# 닭갈비
# 양념장
# 만들기
# .
# 춘천 닭갈비 레시피 김치치즈 닭갈비 양념장 만들기.
# ------------------
# 용
# 볶음
# 용
# 김치
# 담그기
# 차근차근
# 배추
# 김장
# 김치
# 주문
# 은
# 우먼
# 키친
# 에서
# .
# 찌개용 볶음용 김치 담고 기차도 근 차근 배추 김장김치 주문은 우먼 키친에서.
# ------------------
# 김치
# .
# 봄김치.
# ------------------
# 깻잎
# 양념장
# 백종원
# 깻잎
# 김치
# 만드는
# 법
# 깻잎
# 40
# 장
# 깻잎
# 요리
# 반찬
# 레시피
# .
# 맛있는 깻잎 양념장 백종원 깻잎김치 만드는 법 깻잎 40장 깻잎 요리 반찬 레시피.
# ------------------
# 아침밥
# 상
# 순두부찌개
# 파
# 강회
# 곱창
# 돌
# 김구
# 이
# 등
# 갈비
# 묵은지
# 요리
# 로
# 김치전
# 만들기
# 해물
# 김치
# 부치기
# 만드는
# 법
# 무
# 김치
# 지짐
# 김치
# 요리
# 만들기
# .
# 20220214아침밥상순두부찌개파강회곱창돌김구이등갈비묵은지요리로김치전만들기해물김치부치기만드는법무김치지짐김치요리만들기.
# ------------------
# 매운
# 김치
# 실비
# 파김치
# 까지
# .
# 맛있게 매운 김치 실비 파김치까지.
# ------------------
# 집
# 무
# 김치
# 같은
# 꼬들
# 한
# 식감
# JMT
# .
# 설렁탕집 무김치 같은 꼬들꼬들한 식감 JMT.
# ------------------
# 라이스
# 페이퍼
# 말
# 이
# 짧은
# 가족
# 여행
# 태안
# 안면도
# 아일랜드
# 리솜
# 일루
# 글루눈
# 내리는바
# 닷
# 같아안로
# 컬
# 푸드
# 직매
# 장
# .
# 김치볶음밥 라이스페이퍼 말이 짧은 가족여행 태안 안면도 아일랜드리 솜 일루 글루 눈 내리는 바다 같아 안 로컬푸드 직매장.
# ------------------
# 날씨
# 에
# 더욱
# 맛
# 난
# 비법
# .
# 따뜻해진 날씨에 더욱 맛난 비법.
# ------------------
# 달
# 큰
# 봄
# 동
# 겉절이
# 양념
# 봄
# 동무
# 침
# 봄
# 동
# 겉절이
# 양념
# 봄
# 동무
# 침
# 봄
# 동
# 김치
# 봄
# 동
# 요리
# .
# 고소달큰봄동겉절이양념봄동무침봄동겉절이양념봄동무침봄동김치봄동요리.
# ------------------
# 끓이는
# 법
# 해장국
# 드세요
# 시원한
# 국물
# 김치
# 우동
# 만들기
# 얼큰한
# 우동
# 만드는
# 법
# 명절
# 느끼한
# 속
# 개운해지는
# 알토
# 란
# 총각김치
# 담그는
# 방법
# 예쁜
# 가을
# 알
# 타
# 리무
# 만났을
# 때
# 알
# 타리
# 김치
# 와
# 꽁치
# 가
# 만나
# 꽁치
# 김치찌개
# 맛있게
# 끓이는
# 법
# 2월
# 제철해산물
# 바지락
# 순두부찌개
# 레시피
# 재료
# 주말
# 메뉴
# .
# 떡국 끓이는 법해 장국 드세요 시원한 국물김치 가락국수 만들기 얼큰한 가락국수 만드는 법명이 절 느끼한 속개 운해 지는 알토란 총각김치 담그는 방법 예쁜 가을 총각무 만났을 때 총각김치와 꽁치가 만나 꽁치김치찌개 맛있게 끓이는 법 2월 제철 해산물 바지락 순두부찌개 레시피 재료 주말 메뉴.
# ------------------
# 맛없을
# 때
# 끓
# 여보세요
# 밥
# 3
# 공기
# 비웠습니다
# 돼지
# 등뼈
# 묵은지
# 김치
# 찜
# 레시피
# 묵은지
# 지짐
# .
# 밥맛없을 때 끓여보세요 밥 3공기 비웠습니다 돼지등뼈 묵은 지 김치찜 레시피 묵은지 지짐.
# ------------------
# 저녁
# 뭐
# 먹지
# 돼지고기
# 김치찌개
# 맛
# 난
# 수제
# 만
# 둣집
# 진한
# 김치
# 어묵
# 탕
# 레시피
# .
# 오늘 저녁 뭐 먹지 돼지고기 김치찌개 맛난 수제 만둣집 진한 김치 어묵탕 레시피.
# ------------------
# 끓이는
# 법
# 보글보글
# 어묵
# 투하
# 청국장
# 찌개
# 레시피
# .
# 순두부찌개 끓이는 법 보글보글 어묵 투하 청국장찌개 레시피.
# ------------------
# 파김치
# 대
# 파의
# 단맛
# 이
# 일품
# 부드러운
# 김치
# .
# 대파 김치 대파의 단맛이 일품 부드러운 김치.
# ------------------
# 메뉴
# 계란
# 참치
# 김치
# 김밥
# 상추
# 깻잎
# 넣은
# 참치
# 김밥
# .
# 온 밥 메뉴 계란 참치김치 김밥 상추 깻잎 넣은 참치 김밥.
# ------------------
# 맛없을
# 때
# 끓
# 여보세요
# .
# 밥맛없을 때 끓여보세요.
# ------------------
# 명절
# 전
# 종류
# .
# 남은 명절 전 종류.
# ------------------
# 김치
# 찜
# 갓김치
# 통조림
# 고등어
# 조림
# 만드는
# 법
# 삼겹살
# 돼지고기
# 김치찌개
# 레시피
# 초
# 간단
# 백종원
# 김치볶음밥
# 레리시
# 고슬고슬
# .
# 사태 김치찜 갓김치 통조림 고등어조림 만드는 법 삼겹살 돼지고기 김치찌개 레시피 초간 단 백종원 김치볶음밥 레리시고 슬고 술.
# ------------------
# 만드는
# 법
# 낙지
# 는
# 듬뿍
# 김치전
# 은
# 겉바
# 속
# 촉
# .
# 무생채 만드는 법 낙지는 듬뿍 김치전은 겉나 석촉.
# ------------------
# 김치찌개
# .
# 꽁치김치찌개.
# ------------------
# 김치볶음밥
# 누룽지
# 만들기
# .
# 바삭바삭 김치볶음밥 누룽지 만들기.
# ------------------
# 허니
# 제이
# 김치
# 요리
# 로
# .
# 나 혼자 산다 허니 제이 김치요리로.
# ------------------
# 한
# 양념
# 묵은지
# 고등어
# 조림
# 만드는
# 법
# 5분
# 한
# 그릇
# 요리
# .
# 매콤한 양념 묵은지 고등어조림 만드는 법 5 분한 그릇 요리.
# ------------------
# 가루
# 듬뿍
# 참치
# 김치
# 주먹밥
# 간단
# 아침
# 메뉴
# 김치
# 국밥
# 갱
# 시기
# 죽
# 갱
# 시기
# 죽
# 만드는
# 법
# 집
# 김밥
# 최고
# 남은
# 설날
# 음식
# 묵은지
# 김밥
# 만들기
# 간단
# 한
# 그릇
# 신
# 김치
# 볶음
# 볶음
# 김치
# 에요
# .
# 김가루듬뿍참치김치주먹밥간단아침메뉴김치국밥갱시기죽갱시기죽만드는법집김밥최고남은설날음식묵은지김밥만들기간단한그릇신김치볶음볶음김치에요.
# ------------------
# 목살
# 김치찌개
# 맛있게
# 끓이는
# 돼지
# 삼겹살
# 김치찌개
# 레시피
# 김치찌개
# 맛있게
# 끓이는
# 돼지
# 삼겹살
# 김치찌개
# 만두전골
# 코
# 박고
# 퍼
# 먹었네요
# .
# 돼지목살 김치찌개 맛있게 끓이는 돼지 삼겹살 김치찌개 레시피 김치찌개 맛있게 끓이는 돼지 삼겹살 김치찌개 만두전골 코 박고 퍼먹었네요.
# ------------------
# 짭
# 짤
# 이
# 토마토
# 제철
# 토마토
# 김치
# 토마토
# 겉절이
# 만드는
# 법
# 의외로
# 간단하죠
# .
# 대저 짭짤히 토마토 제철 토마토 김치 토마토 겉절이 만드는 법의 외로 간단하죠.
# ------------------
# 무한
# 부쳐
# .
# 김치부침개 무한 부쳐.
# ------------------
# 남은
# 음식
# 은
# 김치
# 국물
# 부대찌개
# 만드는
# 법
# 이
# 거
# 죠
# .
# 명절 남은 음식은 김치 국물 부대찌개 만드는 법이 거죠.
# ------------------
# 입
# 에
# 착착
# 붙는
# 맛
# .
# 오독오독 입에 착착 붙는 맛.
# ------------------
# 비지
# 만드는
# 법
# 뒤집
# 개
# 없이
# 쉽게
# 뒤집는
# 방법
# .
# 콩비지 만드는 법 뒤집개 없이 쉽게 뒤집는 방법.
# ------------------
# 김치
# 실비
# 파김치
# 까지
# .
# 실비 김치 실비 파김치까지.
# ------------------
# 타
# 리무
# 만났을
# 때
# 알
# 타리
# 김치
# 지짐
# 누름
# 적
# 묵은지
# 요리
# 반찬
# .
# 알타리무만났을때알타리김치지짐누름적묵은지요리반찬.
# ------------------
# 꽁치
# 김치찌개
# 만드는
# 법
# 칼
# 만두
# 진한
# 국물
# 매콤
# 한
# 양념
# 묵은지
# 고등어
# 조림
# .
# 통조림 꽁치김치찌개 만드는 법 칼마 두진 한국물 매콤한 양념 묵은지 고등어조림.
# ------------------
# 진한
# 김치
# 어묵
# 우동
# 만드는
# 법
# 배추김치
# 담그기
# 배추김치
# 양념
# .
# 풀무원 진한 김치 어묵 가락국수 만드는 법 배추김치 담그기 배추김치 양념.
# ------------------
# 묵은지
# 멸치
# 볶음
# 냉파
# 요리
# 신
# 김치
# 냉이
# 국
# 아침
# 국
# 만들기
# 콩나물
# 요리
# 김치
# 굴전
# 바삭
# 하게
# 부침개
# 만드는
# 법
# 모두
# 가
# 엄지
# 척
# .
# 구수한 묵은지 멸치볶음 냉하 요리 신 김치 냉잇국 아침 국 만들기 콩나물 요리 김치 굴전 바삭하게 부침개 만드는 법 모두가 엄지 척.
# ------------------
# 음식
# 대패
# 삼겹살
# 볶음
# 어묵
# 볶음
# 김치
# 에요
# .
# 다이어트 음식 대패삼겹살볶음 어묵볶음김치에요.
# ------------------
# 때
# 딱
# 참치
# 김치전
# 김치부침개
# .
# 출출할 때 딱 참치김치전 김치부침개.
# ------------------
# 저녁
# 가
# 쓰
# 오브
# 시
# 우동
# 과
# 김치
# 를
# 넣어서
# 더
# 맛있는
# 굴
# 부침개
# 만들기
# .
# 오늘 저녁 가쓰 오브 시운동과 김치를 넣어서 더 맛있는 굴 부침개 만들기.
# ------------------
# 닭볶음탕
# 신
# 김치
# 어묵
# 탕
# 총
# 각
# 무
# 김치
# 담그는
# 방법
# 맛
# 보장
# 백종원
# 김치볶음밥
# 레리시
# 고슬고슬
# .
# 국물닭볶음탕신김치어묵탕총각무김치담그는방법맛보장백종원김치볶음밥레리시고슬고슬.
# ------------------
# 만드는
# 법
# 김장
# 김치
# 넣고
# 바글바글
# 청국장
# 찌개
# 종류
# .
# 두부김치 만드는 법 김장김치 넣고 바글바글 청국장찌개 종류.
# ------------------
# 만드는
# 법
# 메밀
# 요리
# 한국
# 전통
# 음식
# 막걸리
# 안주
# .
# 부추김치 만드는 법 메밀요리 한국 전통음식 막걸리 안주.
# ------------------
# 김치
# 추천
# .
# 전라도 김치 추천.
# ------------------
# 둠
# 신
# 김치
# 김치찌개
# 끓이는
# 법
# 맛
# 보장
# 상큼
# 한
# 깻잎
# 김치
# 만드는
# 법
# 맛있는
# 김치부침개
# 레시피
# 톡톡
# 식감
# 좋은
# 날치
# 알
# 볶음밥
# 톡톡
# 씹히는
# 날치
# 알
# 볶음밥
# 톡톡
# 씹히는
# 날치
# 알
# 볶음밥
# 톡톡
# 씹히는
# 날치
# 알
# 볶음밥
# 톡톡
# 씹히는
# 날치
# 알
# 요리
# .
# 모둠 신 김치 김치찌개 끓이는 법 맛 보장 상큼한 깻잎김치 만드는 법 맛있는 김치부침개 레시피 톡 톡식 감 좋은 날치알 볶음밥 톡톡 씹히는 날치알 볶음밥 톡톡 씹히는 날치알 볶음밥 톡톡 씹히는 날치알 볶음밥 톡톡 씹히는 날치알 요리.
# ------------------
# 동치미
# 파김치
# 입
# 에
# 착착
# 붙는
# 맛
# .
# 겨울 동치미 파김치 입에 착착 붙는 맛.
# ------------------
# 김치
# 볶음
# 천혜향
# 도시락
# 앨범
# .
# 신 김치볶음 천혜향 도시락 앨범.
# ------------------
# 과
# 김치
# 로
# 돼지고기
# 두루치기
# 만드는
# 법
# 돼지
# 앞다리
# 살
# 김치찌개
# 끓이기
# .
# 삼겹살과 김치로 돼지고기 두루치기 만드는 법 돼지 앞다리살 김치찌개 끓이기.
# ------------------
# 구이
# 집
# 에서
# 갓김치
# 삼겹살
# 굽기
# 좋으네요
# .
# 삼겹 살구 잇집에서 갓김치 삼겹살 굽기 좋네요.
# ------------------
# 김장
# 김치
# 만들기
# .
# 굴 김장김치 만들기.
# ------------------
# 스케치
# 432
# 콩
# 마니
# 밥
# 추추
# 추어탕
# 멸추
# 볶음
# 배추김치
# 미니
# 사과
# 도시락
# 앨범
# .
# 도시락스케치432콩마니밥추추추어탕멸추볶음배추김치미니사과도시락앨범.
# ------------------
# 새우
# 젓갈
# 추젓
# 김장
# 새우젓
# 나눔
# 이벤트
# 만능
# 김치
# 양념
# 깻잎
# 양념장
# 백종원
# 깻잎
# 김치
# 만드는
# 법
# 김치부침개
# .
# 홍 새우 젓갈 추젓 김장 새우젓 나눔 이벤트 만능 김치 양념깻잎 양념장 백종원 깻잎김치 만드는 법 김치부침개.
# ------------------
# 새우
# 장
# 만능
# 김치
# 양념
# 중요하지
# .
# 양념 새우 장만 능김치 양념 중요하지.
# ------------------
# 밥
# 반찬
# 깻잎
# 요리
# .
# 쉬운 밥반찬 깻잎 요리.
# ------------------
# 별
# 미전
# 김치전
# 만들기
# 역시
# 김치전
# 반죽
# 이
# .
# 겨울철 별이 전 김치전 만들기 역시 김치 전 반죽이.
# ------------------
# 국밥
# 해장
# 음식
# .
# 콩나물국밥 해장음식.
# ------------------
# 분
# 수육
# 보쌈
# 무
# 김치
# 까지
# .
# 무수운 수육 보쌈 무김치까지.
# ------------------
